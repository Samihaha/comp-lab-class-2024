# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

# %%
def get_github_file(owner, repo, filepath, branch):
    # Construct the URL for the raw file
    url = f'https://raw.githubusercontent.com/{owner}/{repo}/{branch}/{filepath}'
    response = requests.get(url)
    response.raise_for_status()  # Raise an error for bad responses
    return response.text  # Return the content of the file

# %%
if __name__ == "__main__":
    owner = 'Samihaha'
    repo = 'comp-lab-class-2024'
    filepath = 'Week2-DataAnalysis/Data/1hz3_T310.run.25000000.energy.xvg'  # Path to the data file
    branch = 'main'  # The correct branch name

    # Fetch the file content
    file_content = get_github_file(owner, repo, filepath, branch)

# %%
if file_content:
        # Use StringIO to load the data into a pandas DataFrame
        data = pd.read_csv(StringIO(file_content), delim_whitespace=True, comment='#', header=None)

        # Display the first few rows of the dataframe to understand its structure
        print(data.head())
       # b) Create separate plots for each quantity vs. time
        # The first column is assumed to be time in ps, convert to ns for plotting
        time_ns = data[0] / 1000  # Convert ps to ns
     # List of quantities
        quantities = {
            'Kinetic Energy': data[1],
            'Potential Energy': data[2],
            'Total Energy': data[3],
            'Temperature': data[4],
            'Pressure': data[5],
            'Volume': data[6]
        }
# Out:
#        0              1             2              3           4           5  \
# 0    0.0 -175680.937500  35128.644531 -140552.296875  309.853302   84.967438
# 1  100.0 -175387.062500  35737.015625 -139650.046875  315.219452  116.084549
# 2  200.0 -175059.531250  35401.789062 -139657.750000  312.262573  -85.727356
# 3  300.0 -175760.984375  35717.289062 -140043.687500  315.045502  269.017548
# 4  400.0 -174898.718750  35252.562500 -139646.156250  310.946320 -129.284088
#
#             6
# 0  137.956879
# 1  137.819077
# 2  137.437531
# 3  135.811859
# 4  137.846680

# %%
    if file_content:
        # Use StringIO to load the data into a pandas DataFrame
        data = pd.read_csv(StringIO(file_content), delim_whitespace=True, comment='#', header=None)

        # Display the first few rows of the dataframe to understand its structure
        print(data.head())

        # b) Create separate plots for each quantity vs. time
        # The first column is assumed to be time in ps, convert to ns for plotting
        time_ns = data[0] / 1000  # Convert ps to ns

        # List of quantities
        quantities = {
            'Kinetic Energy': data[1],
            'Potential Energy': data[2],
            'Total Energy': data[3],
            'Temperature': data[4],
            'Pressure': data[5],
            'Volume': data[6]
        }

        # Plot each quantity
        plt.figure(figsize=(12, 10))

        for i, (label, values) in enumerate(quantities.items(), 1):
            plt.subplot(3, 2, i)
            plt.plot(time_ns, values, label=label)
            plt.title(label)
            plt.xlabel('Time (ns)')
            plt.ylabel(label)
            plt.grid()
            plt.legend()

        plt.tight_layout()
        plt.show()

        # c) Plot kinetic energy and temperature on the same plot
        fig, ax1 = plt.subplots(figsize=(10, 6))

        # Plot kinetic energy on the left y-axis
        ax1.set_xlabel('Time (ns)')
        ax1.set_ylabel('Kinetic Energy (kJ/mol)', color='tab:red')
        ax1.plot(time_ns, quantities['Kinetic Energy'], color='tab:red', label='Kinetic Energy')
        ax1.tick_params(axis='y', labelcolor='tab:red')

        # Create a second y-axis for temperature
        ax2 = ax1.twinx()
        ax2.set_ylabel('Temperature (K)', color='tab:blue')
        ax2.plot(time_ns, quantities['Temperature'], color='tab:blue', label='Temperature')
        ax2.tick_params(axis='y', labelcolor='tab:blue')

        # Title and grid
        plt.title('Kinetic Energy and Temperature vs Time')
        fig.tight_layout()  # Adjust layout to prevent overlap
        plt.grid()
        plt.show()
# Out:
#        0              1             2              3           4           5  \
# 0    0.0 -175680.937500  35128.644531 -140552.296875  309.853302   84.967438
# 1  100.0 -175387.062500  35737.015625 -139650.046875  315.219452  116.084549
# 2  200.0 -175059.531250  35401.789062 -139657.750000  312.262573  -85.727356
# 3  300.0 -175760.984375  35717.289062 -140043.687500  315.045502  269.017548
# 4  400.0 -174898.718750  35252.562500 -139646.156250  310.946320 -129.284088
#
#             6
# 0  137.956879
# 1  137.819077
# 2  137.437531
# 3  135.811859
# 4  137.846680
