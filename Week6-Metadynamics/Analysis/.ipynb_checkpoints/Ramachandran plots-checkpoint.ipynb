# %%
# Load the COLVAR files, specifying that there are three columns: time, phi, and psi.
colvar_a = np.loadtxt('/home/sa8200/comp-lab-class/comp-lab-class-2024/Week6-Metadynamics/Inputs/StateA/COLVAR', comments='#', usecols=(0, 1, 2))
colvar_b = np.loadtxt('/home/sa8200/comp-lab-class/comp-lab-class-2024/Week6-Metadynamics/Inputs/StateB/COLVAR', comments='#', usecols=(0, 1, 2))

# Extract phi and psi dihedral angles (columns 1 and 2)
phi_a_colvar = colvar_a[:, 1]  # Column index 1 for phi
psi_a_colvar = colvar_a[:, 2]  # Column index 2 for psi
phi_b_colvar = colvar_b[:, 1]
psi_b_colvar = colvar_b[:, 2]

# Calculate standard deviations
phi_a_std = np.std(phi_a_colvar)
psi_a_std = np.std(psi_a_colvar)
phi_b_std = np.std(phi_b_colvar)
psi_b_std = np.std(psi_b_colvar)

phi_a_std, psi_a_std, phi_b_std, psi_b_std
# Out:
# (0.5568802296838808,
#  1.0294566128425275,
#  0.13213973950615396,
#  0.34165445114938153)

# %%
import mdtraj as md
import numpy as np
import matplotlib.pyplot as plt

# Load the trajectory and topology
traj = md.load('/home/sa8200/comp-lab-class/comp-lab-class-2024/Week6-Metadynamics/Inputs/StateA/traj_comp.xtc', top='/home/sa8200/comp-lab-class/comp-lab-class-2024/Week6-Metadynamics/Inputs/StateA/dialaA.pdb')

# Compute phi and psi angles
phi_indices, phi_angles = md.compute_phi(traj_a)
psi_indices, psi_angles = md.compute_psi(traj_a)

# Convert radians to degrees for better interpretation
phi_angles_deg = np.rad2deg(phi_angles)
psi_angles_deg = np.rad2deg(psi_angles)

# %%
def compute_fes(phi, psi, bins=25):
    # Ensure input is a NumPy array
    phi = np.asarray(phi).flatten()
    psi = np.asarray(psi).flatten()

    # Create 2D histogram
    hist, xedges, yedges = np.histogram2d(phi, psi, bins=bins, range=[[-180, 180], [-180, 180]])

    # Compute FES
    fes = -np.log(hist + 1e-10)  # Add small value to avoid log(0)
    fes -= np.min(fes)  # Normalize FES

    return fes, xedges, yedges

# %%
# Load the trajectory and topology
traj = md.load('/home/sa8200/comp-lab-class/comp-lab-class-2024/Week6-Metadynamics/Inputs/StateA/traj_comp.xtc', top='/home/sa8200/comp-lab-class/comp-lab-class-2024/Week6-Metadynamics/Inputs/StateA/dialaA.pdb')

# Compute phi and psi angles
_, phi_angles = md.compute_phi(traj_a)
_, psi_angles = md.compute_psi(traj_a)

# Convert radians to degrees for better interpretation
phi_angles_deg = np.rad2deg(phi_angles).flatten()
psi_angles_deg = np.rad2deg(psi_angles).flatten()

# Call the function to compute the FES
fes, xedges, yedges = compute_fes(phi_angles_deg, psi_angles_deg)

# Create a meshgrid for plotting
X, Y = np.meshgrid(xedges[:-1], yedges[:-1])

# Plot the Free Energy Surface (FES)
plt.figure(figsize=(8, 6))
plt.imshow(fes.T, origin='lower', extent=[-180, 180, -180, 180], cmap='viridis', aspect='auto')
plt.xlabel('Phi (degrees)')
plt.ylabel('Psi (degrees)')
plt.title('Ramachandran plot for A')
plt.show()

# %%
import mdtraj as md
import numpy as np
import matplotlib.pyplot as plt

# Load the trajectory and topology
traj = md.load('/home/sa8200/comp-lab-class/comp-lab-class-2024/Week6-Metadynamics/Inputs/StateB/traj_comp.xtc', top='/home/sa8200/comp-lab-class/comp-lab-class-2024/Week6-Metadynamics/Inputs/StateB/dialaB.pdb')

# Compute phi and psi angles
phi_indices, phi_angles = md.compute_phi(traj_b)
psi_indices, psi_angles = md.compute_psi(traj_b)

# Convert radians to degrees for better interpretation
phi_angles_deg = np.rad2deg(phi_angles)
psi_angles_deg = np.rad2deg(psi_angles)

# %%
def compute_fes(phi, psi, bins=25):
    # Ensure input is a NumPy array
    phi = np.asarray(phi).flatten()
    psi = np.asarray(psi).flatten()

    # Create 2D histogram
    hist, xedges, yedges = np.histogram2d(phi, psi, bins=bins, range=[[-180, 180], [-180, 180]])

    # Compute FES
    fes = -np.log(hist + 1e-10)  # Add small value to avoid log(0)
    fes -= np.min(fes)  # Normalize FES

    return fes, xedges, yedges

# %%
# Load the trajectory and topology
traj = md.load('/home/sa8200/comp-lab-class/comp-lab-class-2024/Week6-Metadynamics/Inputs/StateB/traj_comp.xtc', top='/home/sa8200/comp-lab-class/comp-lab-class-2024/Week6-Metadynamics/Inputs/StateB/dialaB.pdb')

# Compute phi and psi angles
_, phi_angles = md.compute_phi(traj_b)
_, psi_angles = md.compute_psi(traj_b)

# Convert radians to degrees for better interpretation
phi_angles_deg = np.rad2deg(phi_angles).flatten()
psi_angles_deg = np.rad2deg(psi_angles).flatten()

# Call the function to compute the FES
fes, xedges, yedges = compute_fes(phi_angles_deg, psi_angles_deg)

# Create a meshgrid for plotting
X, Y = np.meshgrid(xedges[:-1], yedges[:-1])

# Plot the Free Energy Surface (FES)
plt.figure(figsize=(8, 6))
plt.imshow(fes.T, origin='lower', extent=[-180, 180, -180, 180], cmap='viridis', aspect='auto')
plt.xlabel('Phi (degrees)')
plt.ylabel('Psi (degrees)')
plt.title('Ramachandran plot for B')
plt.show()
